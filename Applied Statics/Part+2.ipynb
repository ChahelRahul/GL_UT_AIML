# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
Team = pd.read_csv('DS - Part2 - Basketball.csv',index_col=0)

# %%
Team
# Out:
#          Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# Team
# Team 1           86  4385        2762     1647        552       563
# Team 2           86  4262        2762     1581        573       608
# Team 3           80  3442        2614     1241        598       775
# Team 4           82  3386        2664     1187        616       861
# Team 5           86  3368        2762     1209        633       920
# ...             ...   ...         ...      ...        ...       ...
# Team 57           1    34          38        8         10        20
# Team 58           1    22          30        7          8        15
# Team 59           1    19          30        7          5        18
# Team 60           1    14          30        5          4        21
# Team 61           1     -           -        -          -         -
#
#         BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# Team
# ...

# %%
Team.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, Team 1 to Team 61
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Tournament           61 non-null     int64
#  1   Score                61 non-null     object
#  2   PlayedGames          61 non-null     object
#  3   WonGames             61 non-null     object
#  4   DrawnGames           61 non-null     object
#  5   LostGames            61 non-null     object
#  6   BasketScored         61 non-null     object
#  7   BasketGiven          61 non-null     object
#  8   TournamentChampion   61 non-null     object
#  9   Runner-up            61 non-null     object
#  10  TeamLaunch           61 non-null     object
#  11  HighestPositionHeld  61 non-null     int64
# dtypes: int64(2), object(10)
# memory usage: 6.2+ KB

# %%
Team['TournamentChampion'] = Team['TournamentChampion'].replace('-', 0)
Team['Runner-up'] = Team['Runner-up'].replace('-', 0)
Team['TeamLaunch'] = Team['TeamLaunch'].str[0:4]
Team.iloc[60]=Team.iloc[60].replace('-', 0)

# %%
Team[Team.columns]=Team[Team.columns].apply(pd.to_numeric)

# %%
Team.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, Team 1 to Team 61
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Tournament           61 non-null     int64
#  1   Score                61 non-null     int64
#  2   PlayedGames          61 non-null     int64
#  3   WonGames             61 non-null     int64
#  4   DrawnGames           61 non-null     int64
#  5   LostGames            61 non-null     int64
#  6   BasketScored         61 non-null     int64
#  7   BasketGiven          61 non-null     int64
#  8   TournamentChampion   61 non-null     int64
#  9   Runner-up            61 non-null     int64
#  10  TeamLaunch           61 non-null     int64
#  11  HighestPositionHeld  61 non-null     int64
# dtypes: int64(12)
# memory usage: 6.2+ KB

# %%
Team
# Out:
#          Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# Team
# Team 1           86   4385         2762      1647         552        563
# Team 2           86   4262         2762      1581         573        608
# Team 3           80   3442         2614      1241         598        775
# Team 4           82   3386         2664      1187         616        861
# Team 5           86   3368         2762      1209         633        920
# ...             ...    ...          ...       ...         ...        ...
# Team 57           1     34           38         8          10         20
# Team 58           1     22           30         7           8         15
# Team 59           1     19           30         7           5         18
# Team 60           1     14           30         5           4         21
# Team 61           1      0            0         0           0          0
#
#          BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# ...

# %%
Team.describe()
# Out:
#        Tournament        Score  PlayedGames     WonGames  DrawnGames  \
# count   61.000000    61.000000    61.000000    61.000000   61.000000
# mean    24.000000   901.426230   796.819672   303.967213  188.934426
# std     26.827225  1134.899121   876.282765   406.991030  201.799477
# min      1.000000     0.000000     0.000000     0.000000    0.000000
# 25%      4.000000    96.000000   114.000000    34.000000   24.000000
# 50%     12.000000   375.000000   423.000000   123.000000   95.000000
# 75%     38.000000  1351.000000  1318.000000   426.000000  330.000000
# max     86.000000  4385.000000  2762.000000  1647.000000  633.000000
#
#          LostGames  BasketScored  BasketGiven  TournamentChampion  Runner-up  \
# count    61.000000     61.000000    61.000000           61.000000  61.000000
# mean    303.754098   1140.344262  1140.229508            1.426230   1.409836
# std     294.708594   1506.740211  1163.710766            5.472535   4.540107
# ...

# %%
#univarient analysis


plt.figure(figsize=(20,6))
plt.subplot(1, 3, 1)
plt.title('Tournament')
sns.distplot(Team['Tournament'],color='green')

# subplot 2
plt.subplot(1, 3, 2)
plt.title('Score')
sns.distplot(Team['Score'],color='blue')

# subplot 3l
plt.subplot(1, 3, 3)
plt.title('WonGames')
sns.distplot(Team['WonGames'],color='red')

plt.figure(figsize=(20,6))
plt.subplot(1, 3, 1)
plt.title('Tournament')
sns.boxplot(Team['Tournament'],orient='vertical',color='green')

# subplot 2
plt.subplot(1, 3, 2)
plt.title('Score')
sns.boxplot(Team['Score'],orient='vertical',color='blue')

# subplot 3
plt.subplot(1, 3, 3)
plt.title('WonGames')
sns.boxplot(Team['WonGames'],orient='vertical',color='red')


plt.show()

# %%
Team.plot.scatter(x='TournamentChampion',y='PlayedGames',c='red',s=50,figsize=(12,3))
# Out:
# <AxesSubplot:xlabel='TournamentChampion', ylabel='PlayedGames'>

# %%
Team.plot.scatter(x='TournamentChampion',y='Runner-up',c='red',s=50,figsize=(12,3))
# Out:
# <AxesSubplot:xlabel='TournamentChampion', ylabel='Runner-up'>

# %%
Team.plot.scatter(x='PlayedGames',y='WonGames',c='red',s=50,figsize=(12,3))
# Out:
# <AxesSubplot:xlabel='PlayedGames', ylabel='WonGames'>

# %%
sns.jointplot(x = "PlayedGames", y="WonGames", data=Team, kind = 'kde')

# %%
sns.jointplot(x='BasketScored',y='BasketGiven',data=Team)

# %%
print("Oldest Team in the given Data set")
Team[Team['TeamLaunch'] == 1929]
# Out:
# Oldest Team in the given Data set
#          Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# Team
# Team 1           86   4385         2762      1647         552        563
# Team 2           86   4262         2762      1581         573        608
# Team 3           80   3442         2614      1241         598        775
# Team 5           86   3368         2762      1209         633        920
# Team 7           82   2792         2626       948         608       1070
# Team 8           70   2573         2302       864         577        861
# Team 14          44   1416         1428       453         336        639
# Team 45           7    107          130        43          21         66
# Team 52           4     56           72        21          14         37
# Team 54           3     42           54        18           6         30
#
#          BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# Team
# ...

# %%
print("Team with Highest Baskets Scored the given Data set")
Team[Team['BasketScored'] == max(Team['BasketScored'])]
# Out:
# Team with Highest Baskets Scored the given Data set
#         Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# Team
# Team 1          86   4385         2762      1647         552        563
#
#         BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# Team
# Team 1          5947         3140                  33         23        1929
#
#         HighestPositionHeld
# Team
# Team 1                    1

# %%
print("Team with Lowest Baskets Scored the given Data set")
Team[Team['BasketScored'] == min(Team['BasketScored'])].index
#Team 61 dont have data ..We can ignore this team
Team.sort_values('WonGames', ascending=True).head(10)
# Out:
# Team with Lowest Baskets Scored the given Data set
#          Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# Team
# Team 61           1      0            0         0           0          0
# Team 60           1     14           30         5           4         21
# Team 59           1     19           30         7           5         18
# Team 58           1     22           30         7           8         15
# Team 57           1     34           38         8          10         20
# Team 56           1     35           38         8          11         19
# Team 55           2     40           68        13          14         41
# Team 53           2     52           68        17          18         33
# Team 54           3     42           54        18           6         30
# Team 49           2     81           80        19          24         37
#
#          BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# Team
# ...

# %%
corr = Team.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %%
Team['Score/PlayedGames Ratio']=Team['Score']/Team['PlayedGames']
Team['PlayedGames/WonGame Ratio']=Team['PlayedGames']/Team['WonGames']
Team['WonGames/LostGame Ratio']=Team['WonGames']/Team['LostGames']
Team['PlayedGames/BasketGiven Ratio']=Team['PlayedGames']/Team['BasketGiven']

# %%
Team.describe()
# Out:
#        Tournament        Score  PlayedGames     WonGames  DrawnGames  \
# count   61.000000    61.000000    61.000000    61.000000   61.000000
# mean    24.000000   901.426230   796.819672   303.967213  188.934426
# std     26.827225  1134.899121   876.282765   406.991030  201.799477
# min      1.000000     0.000000     0.000000     0.000000    0.000000
# 25%      4.000000    96.000000   114.000000    34.000000   24.000000
# 50%     12.000000   375.000000   423.000000   123.000000   95.000000
# 75%     38.000000  1351.000000  1318.000000   426.000000  330.000000
# max     86.000000  4385.000000  2762.000000  1647.000000  633.000000
#
#          LostGames  BasketScored  BasketGiven  TournamentChampion  Runner-up  \
# count    61.000000     61.000000    61.000000           61.000000  61.000000
# mean    303.754098   1140.344262  1140.229508            1.426230   1.409836
# std     294.708594   1506.740211  1163.710766            5.472535   4.540107
# ...

# %%
Team
# Out:
#          Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# Team
# Team 1           86   4385         2762      1647         552        563
# Team 2           86   4262         2762      1581         573        608
# Team 3           80   3442         2614      1241         598        775
# Team 4           82   3386         2664      1187         616        861
# Team 5           86   3368         2762      1209         633        920
# ...             ...    ...          ...       ...         ...        ...
# Team 57           1     34           38         8          10         20
# Team 58           1     22           30         7           8         15
# Team 59           1     19           30         7           5         18
# Team 60           1     14           30         5           4         21
# Team 61           1      0            0         0           0          0
#
#          BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# ...

# %%
sns.jointplot(x='Score/PlayedGames Ratio',y='WonGames',data=Team)

# %%
Team.sort_values('Score/PlayedGames Ratio', ascending=False).head(10)
# Out:
#          Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# Team
# Team 1           86   4385         2762      1647         552        563
# Team 2           86   4262         2762      1581         573        608
# Team 21          17    970          646       266         172        208
# Team 3           80   3442         2614      1241         598        775
# Team 4           82   3386         2664      1187         616        861
# Team 5           86   3368         2762      1209         633        920
# Team 25          12    553          456       147         112        197
# Team 39           4    190          160        52          45         63
# Team 11          45   1814         1530       563         392        575
# Team 6           73   2819         2408       990         531        887
#
#          BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# Team
# ...

# %%
sns.jointplot(x='Score/PlayedGames Ratio',y='TeamLaunch',data=Team)

# %%
Team.sort_values('PlayedGames/WonGame Ratio', ascending=True).head(10)
# Out:
#          Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# Team
# Team 1           86   4385         2762      1647         552        563
# Team 2           86   4262         2762      1581         573        608
# Team 3           80   3442         2614      1241         598        775
# Team 4           82   3386         2664      1187         616        861
# Team 5           86   3368         2762      1209         633        920
# Team 21          17    970          646       266         172        208
# Team 6           73   2819         2408       990         531        887
# Team 8           70   2573         2302       864         577        861
# Team 11          45   1814         1530       563         392        575
# Team 7           82   2792         2626       948         608       1070
#
#          BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# Team
# ...

# %%
Team.sort_values('PlayedGames/BasketGiven Ratio', ascending=False).head(10)
# Out:
#          Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# Team
# Team 2           86   4262         2762      1581         573        608
# Team 1           86   4385         2762      1647         552        563
# Team 46           3     96          114        26          44         44
# Team 21          17    970          646       266         172        208
# Team 42           6    150          180        53          44         83
# Team 3           80   3442         2614      1241         598        775
# Team 4           82   3386         2664      1187         616        861
# Team 5           86   3368         2762      1209         633        920
# Team 31          12    375          423       123         102        198
# Team 19          27   1148          988       333         256        399
#
#          BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# Team
# ...

# %%
Team.sort_values('WonGames/LostGame Ratio', ascending=False).head(10)
# Out:
#          Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# Team
# Team 1           86   4385         2762      1647         552        563
# Team 2           86   4262         2762      1581         573        608
# Team 3           80   3442         2614      1241         598        775
# Team 4           82   3386         2664      1187         616        861
# Team 5           86   3368         2762      1209         633        920
# Team 21          17    970          646       266         172        208
# Team 6           73   2819         2408       990         531        887
# Team 8           70   2573         2302       864         577        861
# Team 11          45   1814         1530       563         392        575
# Team 9           58   2109         1986       698         522        766
#
#          BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# Team
# ...

# %%
sns.pairplot(Team, y_vars='WonGames', x_vars=["BasketScored", "PlayedGames",
                                                       'Score',"TournamentChampion"])
plt.show()

# %% [markdown]
# #
#     Please include any improvements or suggestions to the association management on quality, quantity, variety, velocity,
# veracity etc. on the data points collected by the association to perform a better data analysis in future.

# %% [markdown]
#     Data about Intraction of different teams during tournaments and Rating of each Match according to level of team can be helpful to provide more accurate analysis of stats of a team and relative stats
